# %%
import tensorflow as tf
import os, pickle, sys, time
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from utils.MyRAN56_v2 import ResidualAttentionModel_56
from contextlib import redirect_stdout

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print(gpus)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
path = './models'
model_name = '/ran56_v2'
model_path = path + model_name
if not os.path.exists(model_path):
    os.makedirs(model_path)
    print(model_path)
else:
    print(model_path + ' already exists.')

history_path = model_path + '/history'
if not os.path.exists(history_path):
    os.makedirs(history_path)
    print(history_path)
else:
    print(history_path + ' already exists.')

saved_model_path = model_path + '/saved_models'
if not os.path.exists(saved_model_path):
    os.makedirs(saved_model_path)
    print(saved_model_path)
else:
    print(saved_model_path + ' already exists.')

graph_path = model_path + '/graphs'
if not os.path.exists(graph_path):
    os.makedirs(graph_path)
    print(graph_path)
else:
    print(graph_path + ' already exists.')
# Out:
# ./models/ran56_v2 already exists.
# ./models/ran56_v2/history already exists.
# ./models/ran56_v2/saved_models already exists.
# ./models/ran56_v2/graphs already exists.

# %%
cifar10 = tf.keras.datasets.cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20,
                                                          width_shift_range=0.2,
                                                          height_shift_range=0.2,
                                                          horizontal_flip=True,
                                                          validation_split=0.2)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# train_mean = np.mean(X_train, axis=(0,1,2))
# train_std = np.std(X_train, axis=(0,1,2))
# np.save("train_mean.npy", train_mean)
# np.save("train_std.npy", train_std)

train_mean = np.load("train_mean.npy")
train_std = np.load("train_std.npy")

# %%
# X_train = X_train - X_train.mean()
# X_test = X_test - X_test.mean()

# datagen.fit(X_train)

X_train = (X_train - train_mean) / train_std
# X_test = (X_test - X_test.mean())

# We can't use the test set's information at all, that would be biasing the results. So we must use the train set's mean and std to normalize.
X_test = (X_test - train_mean) / train_std

datagen.fit(X_train)

# %%
input_shape = X_train.shape[1:]
output_classes = 10

ran56 = ResidualAttentionModel_56(input_shape, output_classes, learning_type='NAL')

model = ran56.return_Model()

model.compile(tf.keras.optimizers.Adam(), 
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Model_Input (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  Conv1_In (Conv2D)              (None, 32, 32, 32)   864         ['Model_Input[0][0]']
#
#  BN_In (BatchNormalization)     (None, 32, 32, 32)   128         ['Conv1_In[0][0]']
#
#  ReLU_In (Activation)           (None, 32, 32, 32)   0           ['BN_In[0][0]']
#
#  ResUnit_L1_NotAttnModule_1_NoD  (None, 32, 32, 32)  128         ['ReLU_In[0][0]']
#  S (BatchNormalization)
#
#  ResUnit_L2_NotAttnModule_1_NoD  (None, 32, 32, 32)  0           ['ResUnit_L1_NotAttnModule_1_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L3_NotAttnModule_1_NoD  (None, 32, 32, 32)  1024        ['ResUnit_L2_NotAttnModule_1_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L4_NotAttnModule_1_NoD  (None, 32, 32, 32)  128         ['ResUnit_L3_NotAttnModule_1_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L5_NotAttnModule_1_NoD  (None, 32, 32, 32)  0           ['ResUnit_L4_NotAttnModule_1_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L6_NotAttnModule_1_NoD  (None, 32, 32, 32)  9216        ['ResUnit_L5_NotAttnModule_1_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L7_NotAttnModule_1_NoD  (None, 32, 32, 32)  128         ['ResUnit_L6_NotAttnModule_1_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L8_NotAttnModule_1_NoD  (None, 32, 32, 32)  0           ['ResUnit_L7_NotAttnModule_1_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L9_NotAttnModule_1_NoD  (None, 32, 32, 128)  4096       ['ResUnit_L8_NotAttnModule_1_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_NotAttnModule_1_No  (None, 32, 32, 128)  4096       ['ResUnit_L2_NotAttnModule_1_NoDS
#  DS (Conv2D)                                                     [0][0]']
#
#  ResUnit_L11_NotAttnModule_1_No  (None, 32, 32, 128)  0          ['ResUnit_L9_NotAttnModule_1_NoDS
#  DS (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_NotAttnModule_1_NoD
#                                                                  S[0][0]']
#
#  ResUnit_L1_Input-p-1-1_AttnS1-  (None, 32, 32, 128)  512        ['ResUnit_L11_NotAttnModule_1_NoD
#  1 (BatchNormalization)                                          S[0][0]']
#
#  ResUnit_L2_Input-p-1-1_AttnS1-  (None, 32, 32, 128)  0          ['ResUnit_L1_Input-p-1-1_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L3_Input-p-1-1_AttnS1-  (None, 32, 32, 32)  4096        ['ResUnit_L2_Input-p-1-1_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L4_Input-p-1-1_AttnS1-  (None, 32, 32, 32)  128         ['ResUnit_L3_Input-p-1-1_AttnS1-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L5_Input-p-1-1_AttnS1-  (None, 32, 32, 32)  0           ['ResUnit_L4_Input-p-1-1_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L6_Input-p-1-1_AttnS1-  (None, 32, 32, 32)  9216        ['ResUnit_L5_Input-p-1-1_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L7_Input-p-1-1_AttnS1-  (None, 32, 32, 32)  128         ['ResUnit_L6_Input-p-1-1_AttnS1-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L8_Input-p-1-1_AttnS1-  (None, 32, 32, 32)  0           ['ResUnit_L7_Input-p-1-1_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L9_Input-p-1-1_AttnS1-  (None, 32, 32, 128)  4096       ['ResUnit_L8_Input-p-1-1_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_Input-p-1-1_AttnS1  (None, 32, 32, 128)  16384      ['ResUnit_L2_Input-p-1-1_AttnS1-1
#  -1 (Conv2D)                                                     [0][0]']
#
#  ResUnit_L11_Input-p-1-1_AttnS1  (None, 32, 32, 128)  0          ['ResUnit_L9_Input-p-1-1_AttnS1-1
#  -1 (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_Input-p-1-1_AttnS1-
#                                                                  1[0][0]']
#
#  MaxPool_DownSamp-1_Mask_AttnS1  (None, 16, 16, 128)  0          ['ResUnit_L11_Input-p-1-1_AttnS1-
#  -1 (MaxPooling2D)                                               1[0][0]']
#
#  ResUnit_L1_DownSamp-r-1-1_Mask  (None, 16, 16, 128)  512        ['MaxPool_DownSamp-1_Mask_AttnS1-
#  _AttnS1-1 (BatchNormalization)                                  1[0][0]']
#
#  ResUnit_L2_DownSamp-r-1-1_Mask  (None, 16, 16, 128)  0          ['ResUnit_L1_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (Activation)                                          AttnS1-1[0][0]']
#
#  ResUnit_L3_DownSamp-r-1-1_Mask  (None, 16, 16, 32)  4096        ['ResUnit_L2_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (Conv2D)                                              AttnS1-1[0][0]']
#
#  ResUnit_L4_DownSamp-r-1-1_Mask  (None, 16, 16, 32)  128         ['ResUnit_L3_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (BatchNormalization)                                  AttnS1-1[0][0]']
#
#  ResUnit_L5_DownSamp-r-1-1_Mask  (None, 16, 16, 32)  0           ['ResUnit_L4_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (Activation)                                          AttnS1-1[0][0]']
#
#  ResUnit_L6_DownSamp-r-1-1_Mask  (None, 16, 16, 32)  9216        ['ResUnit_L5_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (Conv2D)                                              AttnS1-1[0][0]']
#
#  ResUnit_L7_DownSamp-r-1-1_Mask  (None, 16, 16, 32)  128         ['ResUnit_L6_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (BatchNormalization)                                  AttnS1-1[0][0]']
#
#  ResUnit_L8_DownSamp-r-1-1_Mask  (None, 16, 16, 32)  0           ['ResUnit_L7_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (Activation)                                          AttnS1-1[0][0]']
#
#  ResUnit_L9_DownSamp-r-1-1_Mask  (None, 16, 16, 128)  4096       ['ResUnit_L8_DownSamp-r-1-1_Mask_
#  _AttnS1-1 (Conv2D)                                              AttnS1-1[0][0]']
#
#  ResUnit_L10_DownSamp-r-1-1_Mas  (None, 16, 16, 128)  16384      ['ResUnit_L2_DownSamp-r-1-1_Mask_
#  k_AttnS1-1 (Conv2D)                                             AttnS1-1[0][0]']
#
#  ResUnit_L11_DownSamp-r-1-1_Mas  (None, 16, 16, 128)  0          ['ResUnit_L9_DownSamp-r-1-1_Mask_
#  k_AttnS1-1 (Add)                                                AttnS1-1[0][0]',
#                                                                   'ResUnit_L10_DownSamp-r-1-1_Mask
#                                                                  _AttnS1-1[0][0]']
#
#  MaxPool_DownSamp-2_Mask_AttnS1  (None, 8, 8, 128)   0           ['ResUnit_L11_DownSamp-r-1-1_Mask
#  -1 (MaxPooling2D)                                               _AttnS1-1[0][0]']
#
#  ResUnit_L1_Mid-2r-2-1_Mask_Att  (None, 8, 8, 128)   512         ['MaxPool_DownSamp-2_Mask_AttnS1-
#  nS1-1 (BatchNormalization)                                      1[0][0]']
#
#  ResUnit_L2_Mid-2r-2-1_Mask_Att  (None, 8, 8, 128)   0           ['ResUnit_L1_Mid-2r-2-1_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L3_Mid-2r-2-1_Mask_Att  (None, 8, 8, 32)    4096        ['ResUnit_L2_Mid-2r-2-1_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L4_Mid-2r-2-1_Mask_Att  (None, 8, 8, 32)    128         ['ResUnit_L3_Mid-2r-2-1_Mask_Attn
#  nS1-1 (BatchNormalization)                                      S1-1[0][0]']
#
#  ResUnit_L5_Mid-2r-2-1_Mask_Att  (None, 8, 8, 32)    0           ['ResUnit_L4_Mid-2r-2-1_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L6_Mid-2r-2-1_Mask_Att  (None, 8, 8, 32)    9216        ['ResUnit_L5_Mid-2r-2-1_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L7_Mid-2r-2-1_Mask_Att  (None, 8, 8, 32)    128         ['ResUnit_L6_Mid-2r-2-1_Mask_Attn
#  nS1-1 (BatchNormalization)                                      S1-1[0][0]']
#
#  ResUnit_L8_Mid-2r-2-1_Mask_Att  (None, 8, 8, 32)    0           ['ResUnit_L7_Mid-2r-2-1_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L9_Mid-2r-2-1_Mask_Att  (None, 8, 8, 128)   4096        ['ResUnit_L8_Mid-2r-2-1_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L10_Mid-2r-2-1_Mask_At  (None, 8, 8, 128)   16384       ['ResUnit_L2_Mid-2r-2-1_Mask_Attn
#  tnS1-1 (Conv2D)                                                 S1-1[0][0]']
#
#  ResUnit_L11_Mid-2r-2-1_Mask_At  (None, 8, 8, 128)   0           ['ResUnit_L9_Mid-2r-2-1_Mask_Attn
#  tnS1-1 (Add)                                                    S1-1[0][0]',
#                                                                   'ResUnit_L10_Mid-2r-2-1_Mask_Att
#                                                                  nS1-1[0][0]']
#
#  ResUnit_L1_Mid-2r-2-2_Mask_Att  (None, 8, 8, 128)   512         ['ResUnit_L11_Mid-2r-2-1_Mask_Att
#  nS1-1 (BatchNormalization)                                      nS1-1[0][0]']
#
#  ResUnit_L2_Mid-2r-2-2_Mask_Att  (None, 8, 8, 128)   0           ['ResUnit_L1_Mid-2r-2-2_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L3_Mid-2r-2-2_Mask_Att  (None, 8, 8, 32)    4096        ['ResUnit_L2_Mid-2r-2-2_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L1_SkipConn-1_Mask_Att  (None, 16, 16, 128)  512        ['ResUnit_L11_DownSamp-r-1-1_Mask
#  nS1-1 (BatchNormalization)                                      _AttnS1-1[0][0]']
#
#  ResUnit_L4_Mid-2r-2-2_Mask_Att  (None, 8, 8, 32)    128         ['ResUnit_L3_Mid-2r-2-2_Mask_Attn
#  nS1-1 (BatchNormalization)                                      S1-1[0][0]']
#
#  ResUnit_L2_SkipConn-1_Mask_Att  (None, 16, 16, 128)  0          ['ResUnit_L1_SkipConn-1_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L5_Mid-2r-2-2_Mask_Att  (None, 8, 8, 32)    0           ['ResUnit_L4_Mid-2r-2-2_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L3_SkipConn-1_Mask_Att  (None, 16, 16, 32)  4096        ['ResUnit_L2_SkipConn-1_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L1_Trunk-t-2-1_AttnS1-  (None, 32, 32, 128)  512        ['ResUnit_L11_Input-p-1-1_AttnS1-
#  1 (BatchNormalization)                                          1[0][0]']
#
#  ResUnit_L6_Mid-2r-2-2_Mask_Att  (None, 8, 8, 32)    9216        ['ResUnit_L5_Mid-2r-2-2_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L4_SkipConn-1_Mask_Att  (None, 16, 16, 32)  128         ['ResUnit_L3_SkipConn-1_Mask_Attn
#  nS1-1 (BatchNormalization)                                      S1-1[0][0]']
#
#  ResUnit_L2_Trunk-t-2-1_AttnS1-  (None, 32, 32, 128)  0          ['ResUnit_L1_Trunk-t-2-1_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L7_Mid-2r-2-2_Mask_Att  (None, 8, 8, 32)    128         ['ResUnit_L6_Mid-2r-2-2_Mask_Attn
#  nS1-1 (BatchNormalization)                                      S1-1[0][0]']
#
#  ResUnit_L5_SkipConn-1_Mask_Att  (None, 16, 16, 32)  0           ['ResUnit_L4_SkipConn-1_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L3_Trunk-t-2-1_AttnS1-  (None, 32, 32, 32)  4096        ['ResUnit_L2_Trunk-t-2-1_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L8_Mid-2r-2-2_Mask_Att  (None, 8, 8, 32)    0           ['ResUnit_L7_Mid-2r-2-2_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L6_SkipConn-1_Mask_Att  (None, 16, 16, 32)  9216        ['ResUnit_L5_SkipConn-1_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L4_Trunk-t-2-1_AttnS1-  (None, 32, 32, 32)  128         ['ResUnit_L3_Trunk-t-2-1_AttnS1-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L9_Mid-2r-2-2_Mask_Att  (None, 8, 8, 128)   4096        ['ResUnit_L8_Mid-2r-2-2_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L10_Mid-2r-2-2_Mask_At  (None, 8, 8, 128)   16384       ['ResUnit_L2_Mid-2r-2-2_Mask_Attn
#  tnS1-1 (Conv2D)                                                 S1-1[0][0]']
#
#  ResUnit_L7_SkipConn-1_Mask_Att  (None, 16, 16, 32)  128         ['ResUnit_L6_SkipConn-1_Mask_Attn
#  nS1-1 (BatchNormalization)                                      S1-1[0][0]']
#
#  ResUnit_L5_Trunk-t-2-1_AttnS1-  (None, 32, 32, 32)  0           ['ResUnit_L4_Trunk-t-2-1_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L11_Mid-2r-2-2_Mask_At  (None, 8, 8, 128)   0           ['ResUnit_L9_Mid-2r-2-2_Mask_Attn
#  tnS1-1 (Add)                                                    S1-1[0][0]',
#                                                                   'ResUnit_L10_Mid-2r-2-2_Mask_Att
#                                                                  nS1-1[0][0]']
#
#  ResUnit_L8_SkipConn-1_Mask_Att  (None, 16, 16, 32)  0           ['ResUnit_L7_SkipConn-1_Mask_Attn
#  nS1-1 (Activation)                                              S1-1[0][0]']
#
#  ResUnit_L6_Trunk-t-2-1_AttnS1-  (None, 32, 32, 32)  9216        ['ResUnit_L5_Trunk-t-2-1_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  UpSamp2D-1_Mask_AttnS1-1 (UpSa  (None, 16, 16, 128)  0          ['ResUnit_L11_Mid-2r-2-2_Mask_Att
#  mpling2D)                                                       nS1-1[0][0]']
#
#  ResUnit_L9_SkipConn-1_Mask_Att  (None, 16, 16, 128)  4096       ['ResUnit_L8_SkipConn-1_Mask_Attn
#  nS1-1 (Conv2D)                                                  S1-1[0][0]']
#
#  ResUnit_L10_SkipConn-1_Mask_At  (None, 16, 16, 128)  16384      ['ResUnit_L2_SkipConn-1_Mask_Attn
#  tnS1-1 (Conv2D)                                                 S1-1[0][0]']
#
#  ResUnit_L7_Trunk-t-2-1_AttnS1-  (None, 32, 32, 32)  128         ['ResUnit_L6_Trunk-t-2-1_AttnS1-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  Add_L1_AttnS1-1 (Add)          (None, 16, 16, 128)  0           ['ResUnit_L11_DownSamp-r-1-1_Mask
#                                                                  _AttnS1-1[0][0]',
#                                                                   'UpSamp2D-1_Mask_AttnS1-1[0][0]'
#                                                                  ]
#
#  ResUnit_L11_SkipConn-1_Mask_At  (None, 16, 16, 128)  0          ['ResUnit_L9_SkipConn-1_Mask_Attn
#  tnS1-1 (Add)                                                    S1-1[0][0]',
#                                                                   'ResUnit_L10_SkipConn-1_Mask_Att
#                                                                  nS1-1[0][0]']
#
#  ResUnit_L8_Trunk-t-2-1_AttnS1-  (None, 32, 32, 32)  0           ['ResUnit_L7_Trunk-t-2-1_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  Add_L2_AttnS1-1 (Add)          (None, 16, 16, 128)  0           ['Add_L1_AttnS1-1[0][0]',
#                                                                   'ResUnit_L11_SkipConn-1_Mask_Att
#                                                                  nS1-1[0][0]']
#
#  ResUnit_L9_Trunk-t-2-1_AttnS1-  (None, 32, 32, 128)  4096       ['ResUnit_L8_Trunk-t-2-1_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_Trunk-t-2-1_AttnS1  (None, 32, 32, 128)  16384      ['ResUnit_L2_Trunk-t-2-1_AttnS1-1
#  -1 (Conv2D)                                                     [0][0]']
#
#  ResUnit_L1_UpSamp-r-1-1_Mask_A  (None, 16, 16, 128)  512        ['Add_L2_AttnS1-1[0][0]']
#  ttnS1-1 (BatchNormalization)
#
#  ResUnit_L11_Trunk-t-2-1_AttnS1  (None, 32, 32, 128)  0          ['ResUnit_L9_Trunk-t-2-1_AttnS1-1
#  -1 (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_Trunk-t-2-1_AttnS1-
#                                                                  1[0][0]']
#
#  ResUnit_L2_UpSamp-r-1-1_Mask_A  (None, 16, 16, 128)  0          ['ResUnit_L1_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (Activation)                                            tnS1-1[0][0]']
#
#  ResUnit_L1_Trunk-t-2-2_AttnS1-  (None, 32, 32, 128)  512        ['ResUnit_L11_Trunk-t-2-1_AttnS1-
#  1 (BatchNormalization)                                          1[0][0]']
#
#  ResUnit_L3_UpSamp-r-1-1_Mask_A  (None, 16, 16, 32)  4096        ['ResUnit_L2_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (Conv2D)                                                tnS1-1[0][0]']
#
#  ResUnit_L2_Trunk-t-2-2_AttnS1-  (None, 32, 32, 128)  0          ['ResUnit_L1_Trunk-t-2-2_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L4_UpSamp-r-1-1_Mask_A  (None, 16, 16, 32)  128         ['ResUnit_L3_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (BatchNormalization)                                    tnS1-1[0][0]']
#
#  ResUnit_L3_Trunk-t-2-2_AttnS1-  (None, 32, 32, 32)  4096        ['ResUnit_L2_Trunk-t-2-2_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L5_UpSamp-r-1-1_Mask_A  (None, 16, 16, 32)  0           ['ResUnit_L4_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (Activation)                                            tnS1-1[0][0]']
#
#  ResUnit_L4_Trunk-t-2-2_AttnS1-  (None, 32, 32, 32)  128         ['ResUnit_L3_Trunk-t-2-2_AttnS1-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L6_UpSamp-r-1-1_Mask_A  (None, 16, 16, 32)  9216        ['ResUnit_L5_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (Conv2D)                                                tnS1-1[0][0]']
#
#  ResUnit_L5_Trunk-t-2-2_AttnS1-  (None, 32, 32, 32)  0           ['ResUnit_L4_Trunk-t-2-2_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L7_UpSamp-r-1-1_Mask_A  (None, 16, 16, 32)  128         ['ResUnit_L6_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (BatchNormalization)                                    tnS1-1[0][0]']
#
#  ResUnit_L6_Trunk-t-2-2_AttnS1-  (None, 32, 32, 32)  9216        ['ResUnit_L5_Trunk-t-2-2_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L8_UpSamp-r-1-1_Mask_A  (None, 16, 16, 32)  0           ['ResUnit_L7_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (Activation)                                            tnS1-1[0][0]']
#
#  ResUnit_L7_Trunk-t-2-2_AttnS1-  (None, 32, 32, 32)  128         ['ResUnit_L6_Trunk-t-2-2_AttnS1-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L9_UpSamp-r-1-1_Mask_A  (None, 16, 16, 128)  4096       ['ResUnit_L8_UpSamp-r-1-1_Mask_At
#  ttnS1-1 (Conv2D)                                                tnS1-1[0][0]']
#
#  ResUnit_L10_UpSamp-r-1-1_Mask_  (None, 16, 16, 128)  16384      ['ResUnit_L2_UpSamp-r-1-1_Mask_At
#  AttnS1-1 (Conv2D)                                               tnS1-1[0][0]']
#
#  ResUnit_L8_Trunk-t-2-2_AttnS1-  (None, 32, 32, 32)  0           ['ResUnit_L7_Trunk-t-2-2_AttnS1-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L11_UpSamp-r-1-1_Mask_  (None, 16, 16, 128)  0          ['ResUnit_L9_UpSamp-r-1-1_Mask_At
#  AttnS1-1 (Add)                                                  tnS1-1[0][0]',
#                                                                   'ResUnit_L10_UpSamp-r-1-1_Mask_A
#                                                                  ttnS1-1[0][0]']
#
#  ResUnit_L9_Trunk-t-2-2_AttnS1-  (None, 32, 32, 128)  4096       ['ResUnit_L8_Trunk-t-2-2_AttnS1-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_Trunk-t-2-2_AttnS1  (None, 32, 32, 128)  16384      ['ResUnit_L2_Trunk-t-2-2_AttnS1-1
#  -1 (Conv2D)                                                     [0][0]']
#
#  UpSamp2D-2_Mask_AttnS1-1 (UpSa  (None, 32, 32, 128)  0          ['ResUnit_L11_UpSamp-r-1-1_Mask_A
#  mpling2D)                                                       ttnS1-1[0][0]']
#
#  ResUnit_L11_Trunk-t-2-2_AttnS1  (None, 32, 32, 128)  0          ['ResUnit_L9_Trunk-t-2-2_AttnS1-1
#  -1 (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_Trunk-t-2-2_AttnS1-
#                                                                  1[0][0]']
#
#  Add_L3_AttnS1-1 (Add)          (None, 32, 32, 128)  0           ['UpSamp2D-2_Mask_AttnS1-1[0][0]'
#                                                                  , 'ResUnit_L11_Trunk-t-2-2_AttnS1
#                                                                  -1[0][0]']
#
#  SpcConv_Mask_L1_Attn_S1-1 (Bat  (None, 32, 32, 128)  512        ['Add_L3_AttnS1-1[0][0]']
#  chNormalization)
#
#  SpcConv_Mask_L2_Attn_S1-1 (Act  (None, 32, 32, 128)  0          ['SpcConv_Mask_L1_Attn_S1-1[0][0]
#  ivation)                                                        ']
#
#  SpcConv_Mask_L3_Attn_S1-1 (Con  (None, 32, 32, 128)  16384      ['SpcConv_Mask_L2_Attn_S1-1[0][0]
#  v2D)                                                            ']
#
#  SpcConv_Mask_L4_Attn_S1-1 (Bat  (None, 32, 32, 128)  512        ['SpcConv_Mask_L3_Attn_S1-1[0][0]
#  chNormalization)                                                ']
#
#  SpcConv_Mask_L5_Attn_S1-1 (Act  (None, 32, 32, 128)  0          ['SpcConv_Mask_L4_Attn_S1-1[0][0]
#  ivation)                                                        ',
#                                                                   'SpcConv_Mask_L5_Attn_S1-1[0][0]
#                                                                  ']
#
#  SpcConv_Mask_L7_Attn_S1-1 (Act  (None, 32, 32, 128)  0          ['SpcConv_Mask_L5_Attn_S1-1[1][0]
#  ivation)                                                        ']
#
#  Mult_L1_AttnS1-1 (Multiply)    (None, 32, 32, 128)  0           ['SpcConv_Mask_L7_Attn_S1-1[0][0]
#                                                                  ',
#                                                                   'ResUnit_L11_Trunk-t-2-2_AttnS1-
#                                                                  1[0][0]']
#
#  ResUnit_L1_Output-p-1-1_AttnS1  (None, 32, 32, 128)  512        ['Mult_L1_AttnS1-1[0][0]']
#  -1 (BatchNormalization)
#
#  ResUnit_L2_Output-p-1-1_AttnS1  (None, 32, 32, 128)  0          ['ResUnit_L1_Output-p-1-1_AttnS1-
#  -1 (Activation)                                                 1[0][0]']
#
#  ResUnit_L3_Output-p-1-1_AttnS1  (None, 32, 32, 32)  4096        ['ResUnit_L2_Output-p-1-1_AttnS1-
#  -1 (Conv2D)                                                     1[0][0]']
#
#  ResUnit_L4_Output-p-1-1_AttnS1  (None, 32, 32, 32)  128         ['ResUnit_L3_Output-p-1-1_AttnS1-
#  -1 (BatchNormalization)                                         1[0][0]']
#
#  ResUnit_L5_Output-p-1-1_AttnS1  (None, 32, 32, 32)  0           ['ResUnit_L4_Output-p-1-1_AttnS1-
#  -1 (Activation)                                                 1[0][0]']
#
#  ResUnit_L6_Output-p-1-1_AttnS1  (None, 32, 32, 32)  9216        ['ResUnit_L5_Output-p-1-1_AttnS1-
#  -1 (Conv2D)                                                     1[0][0]']
#
#  ResUnit_L7_Output-p-1-1_AttnS1  (None, 32, 32, 32)  128         ['ResUnit_L6_Output-p-1-1_AttnS1-
#  -1 (BatchNormalization)                                         1[0][0]']
#
#  ResUnit_L8_Output-p-1-1_AttnS1  (None, 32, 32, 32)  0           ['ResUnit_L7_Output-p-1-1_AttnS1-
#  -1 (Activation)                                                 1[0][0]']
#
#  ResUnit_L9_Output-p-1-1_AttnS1  (None, 32, 32, 128)  4096       ['ResUnit_L8_Output-p-1-1_AttnS1-
#  -1 (Conv2D)                                                     1[0][0]']
#
#  ResUnit_L10_Output-p-1-1_AttnS  (None, 32, 32, 128)  16384      ['ResUnit_L2_Output-p-1-1_AttnS1-
#  1-1 (Conv2D)                                                    1[0][0]']
#
#  ResUnit_L11_Output-p-1-1_AttnS  (None, 32, 32, 128)  0          ['ResUnit_L9_Output-p-1-1_AttnS1-
#  1-1 (Add)                                                       1[0][0]',
#                                                                   'ResUnit_L10_Output-p-1-1_AttnS1
#                                                                  -1[0][0]']
#
#  ResUnit_L1_NotAttnModule_2_DS   (None, 32, 32, 128)  512        ['ResUnit_L11_Output-p-1-1_AttnS1
#  (BatchNormalization)                                            -1[0][0]']
#
#  ResUnit_L2_NotAttnModule_2_DS   (None, 32, 32, 128)  0          ['ResUnit_L1_NotAttnModule_2_DS[0
#  (Activation)                                                    ][0]']
#
#  ResUnit_L3_NotAttnModule_2_DS   (None, 32, 32, 64)  8192        ['ResUnit_L2_NotAttnModule_2_DS[0
#  (Conv2D)                                                        ][0]']
#
#  ResUnit_L4_NotAttnModule_2_DS   (None, 32, 32, 64)  256         ['ResUnit_L3_NotAttnModule_2_DS[0
#  (BatchNormalization)                                            ][0]']
#
#  ResUnit_L5_NotAttnModule_2_DS   (None, 32, 32, 64)  0           ['ResUnit_L4_NotAttnModule_2_DS[0
#  (Activation)                                                    ][0]']
#
#  ResUnit_L6_NotAttnModule_2_DS   (None, 16, 16, 64)  36864       ['ResUnit_L5_NotAttnModule_2_DS[0
#  (Conv2D)                                                        ][0]']
#
#  ResUnit_L7_NotAttnModule_2_DS   (None, 16, 16, 64)  256         ['ResUnit_L6_NotAttnModule_2_DS[0
#  (BatchNormalization)                                            ][0]']
#
#  ResUnit_L8_NotAttnModule_2_DS   (None, 16, 16, 64)  0           ['ResUnit_L7_NotAttnModule_2_DS[0
#  (Activation)                                                    ][0]']
#
#  ResUnit_L9_NotAttnModule_2_DS   (None, 16, 16, 256)  16384      ['ResUnit_L8_NotAttnModule_2_DS[0
#  (Conv2D)                                                        ][0]']
#
#  ResUnit_L10_NotAttnModule_2_DS  (None, 16, 16, 256)  32768      ['ResUnit_L2_NotAttnModule_2_DS[0
#   (Conv2D)                                                       ][0]']
#
#  ResUnit_L11_NotAttnModule_2_DS  (None, 16, 16, 256)  0          ['ResUnit_L9_NotAttnModule_2_DS[0
#   (Add)                                                          ][0]',
#                                                                   'ResUnit_L10_NotAttnModule_2_DS[
#                                                                  0][0]']
#
#  ResUnit_L1_Input-p-1-1_AttnS2-  (None, 16, 16, 256)  1024       ['ResUnit_L11_NotAttnModule_2_DS[
#  1 (BatchNormalization)                                          0][0]']
#
#  ResUnit_L2_Input-p-1-1_AttnS2-  (None, 16, 16, 256)  0          ['ResUnit_L1_Input-p-1-1_AttnS2-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L3_Input-p-1-1_AttnS2-  (None, 16, 16, 64)  16384       ['ResUnit_L2_Input-p-1-1_AttnS2-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L4_Input-p-1-1_AttnS2-  (None, 16, 16, 64)  256         ['ResUnit_L3_Input-p-1-1_AttnS2-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L5_Input-p-1-1_AttnS2-  (None, 16, 16, 64)  0           ['ResUnit_L4_Input-p-1-1_AttnS2-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L6_Input-p-1-1_AttnS2-  (None, 16, 16, 64)  36864       ['ResUnit_L5_Input-p-1-1_AttnS2-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L7_Input-p-1-1_AttnS2-  (None, 16, 16, 64)  256         ['ResUnit_L6_Input-p-1-1_AttnS2-1
#  1 (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L8_Input-p-1-1_AttnS2-  (None, 16, 16, 64)  0           ['ResUnit_L7_Input-p-1-1_AttnS2-1
#  1 (Activation)                                                  [0][0]']
#
#  ResUnit_L9_Input-p-1-1_AttnS2-  (None, 16, 16, 256)  16384      ['ResUnit_L8_Input-p-1-1_AttnS2-1
#  1 (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_Input-p-1-1_AttnS2  (None, 16, 16, 256)  65536      ['ResUnit_L2_Input-p-1-1_AttnS2-1
#  -1 (Conv2D)                                                     [0][0]']
#
#  ResUnit_L11_Input-p-1-1_AttnS2  (None, 16, 16, 256)  0          ['ResUnit_L9_Input-p-1-1_AttnS2-1
#  -1 (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_Input-p-1-1_AttnS2-
#                                                                  1[0][0]']
#
#  MaxPool_DownSamp-1_Mask_AttnS2  (None, 8, 8, 256)   0           ['ResUnit_L11_Input-p-1-1_AttnS2-
#  -1 (MaxPooling2D)                                               1[0][0]']
#
# ...
#                                                                  1[0][0]']
#
#  Mult_L1_AttnS3-1 (Multiply)    (None, 8, 8, 512)    0           ['SpcConv_Mask_L7_Attn_S3-1[0][0]
#                                                                  ',
#                                                                   'ResUnit_L11_Trunk-t-2-2_AttnS3-
#                                                                  1[0][0]']
#
#  ResUnit_L1_Output-p-1-1_AttnS3  (None, 8, 8, 512)   2048        ['Mult_L1_AttnS3-1[0][0]']
#  -1 (BatchNormalization)
#
#  ResUnit_L2_Output-p-1-1_AttnS3  (None, 8, 8, 512)   0           ['ResUnit_L1_Output-p-1-1_AttnS3-
#  -1 (Activation)                                                 1[0][0]']
#
#  ResUnit_L3_Output-p-1-1_AttnS3  (None, 8, 8, 128)   65536       ['ResUnit_L2_Output-p-1-1_AttnS3-
#  -1 (Conv2D)                                                     1[0][0]']
#
#  ResUnit_L4_Output-p-1-1_AttnS3  (None, 8, 8, 128)   512         ['ResUnit_L3_Output-p-1-1_AttnS3-
#  -1 (BatchNormalization)                                         1[0][0]']
#
#  ResUnit_L5_Output-p-1-1_AttnS3  (None, 8, 8, 128)   0           ['ResUnit_L4_Output-p-1-1_AttnS3-
#  -1 (Activation)                                                 1[0][0]']
#
#  ResUnit_L6_Output-p-1-1_AttnS3  (None, 8, 8, 128)   147456      ['ResUnit_L5_Output-p-1-1_AttnS3-
#  -1 (Conv2D)                                                     1[0][0]']
#
#  ResUnit_L7_Output-p-1-1_AttnS3  (None, 8, 8, 128)   512         ['ResUnit_L6_Output-p-1-1_AttnS3-
#  -1 (BatchNormalization)                                         1[0][0]']
#
#  ResUnit_L8_Output-p-1-1_AttnS3  (None, 8, 8, 128)   0           ['ResUnit_L7_Output-p-1-1_AttnS3-
#  -1 (Activation)                                                 1[0][0]']
#
#  ResUnit_L9_Output-p-1-1_AttnS3  (None, 8, 8, 512)   65536       ['ResUnit_L8_Output-p-1-1_AttnS3-
#  -1 (Conv2D)                                                     1[0][0]']
#
#  ResUnit_L10_Output-p-1-1_AttnS  (None, 8, 8, 512)   262144      ['ResUnit_L2_Output-p-1-1_AttnS3-
#  3-1 (Conv2D)                                                    1[0][0]']
#
#  ResUnit_L11_Output-p-1-1_AttnS  (None, 8, 8, 512)   0           ['ResUnit_L9_Output-p-1-1_AttnS3-
#  3-1 (Add)                                                       1[0][0]',
#                                                                   'ResUnit_L10_Output-p-1-1_AttnS3
#                                                                  -1[0][0]']
#
#  ResUnit_L1_NotAttnModule_4_NoD  (None, 8, 8, 512)   2048        ['ResUnit_L11_Output-p-1-1_AttnS3
#  S (BatchNormalization)                                          -1[0][0]']
#
#  ResUnit_L2_NotAttnModule_4_NoD  (None, 8, 8, 512)   0           ['ResUnit_L1_NotAttnModule_4_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L3_NotAttnModule_4_NoD  (None, 8, 8, 256)   131072      ['ResUnit_L2_NotAttnModule_4_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L4_NotAttnModule_4_NoD  (None, 8, 8, 256)   1024        ['ResUnit_L3_NotAttnModule_4_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L5_NotAttnModule_4_NoD  (None, 8, 8, 256)   0           ['ResUnit_L4_NotAttnModule_4_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L6_NotAttnModule_4_NoD  (None, 8, 8, 256)   589824      ['ResUnit_L5_NotAttnModule_4_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L7_NotAttnModule_4_NoD  (None, 8, 8, 256)   1024        ['ResUnit_L6_NotAttnModule_4_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L8_NotAttnModule_4_NoD  (None, 8, 8, 256)   0           ['ResUnit_L7_NotAttnModule_4_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L9_NotAttnModule_4_NoD  (None, 8, 8, 1024)  262144      ['ResUnit_L8_NotAttnModule_4_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_NotAttnModule_4_No  (None, 8, 8, 1024)  524288      ['ResUnit_L2_NotAttnModule_4_NoDS
#  DS (Conv2D)                                                     [0][0]']
#
#  ResUnit_L11_NotAttnModule_4_No  (None, 8, 8, 1024)  0           ['ResUnit_L9_NotAttnModule_4_NoDS
#  DS (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_NotAttnModule_4_NoD
#                                                                  S[0][0]']
#
#  ResUnit_L1_NotAttnModule_5_NoD  (None, 8, 8, 1024)  4096        ['ResUnit_L11_NotAttnModule_4_NoD
#  S (BatchNormalization)                                          S[0][0]']
#
#  ResUnit_L2_NotAttnModule_5_NoD  (None, 8, 8, 1024)  0           ['ResUnit_L1_NotAttnModule_5_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L3_NotAttnModule_5_NoD  (None, 8, 8, 256)   262144      ['ResUnit_L2_NotAttnModule_5_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L4_NotAttnModule_5_NoD  (None, 8, 8, 256)   1024        ['ResUnit_L3_NotAttnModule_5_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L5_NotAttnModule_5_NoD  (None, 8, 8, 256)   0           ['ResUnit_L4_NotAttnModule_5_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L6_NotAttnModule_5_NoD  (None, 8, 8, 256)   589824      ['ResUnit_L5_NotAttnModule_5_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L7_NotAttnModule_5_NoD  (None, 8, 8, 256)   1024        ['ResUnit_L6_NotAttnModule_5_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L8_NotAttnModule_5_NoD  (None, 8, 8, 256)   0           ['ResUnit_L7_NotAttnModule_5_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L9_NotAttnModule_5_NoD  (None, 8, 8, 1024)  262144      ['ResUnit_L8_NotAttnModule_5_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_NotAttnModule_5_No  (None, 8, 8, 1024)  1048576     ['ResUnit_L2_NotAttnModule_5_NoDS
#  DS (Conv2D)                                                     [0][0]']
#
#  ResUnit_L11_NotAttnModule_5_No  (None, 8, 8, 1024)  0           ['ResUnit_L9_NotAttnModule_5_NoDS
#  DS (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_NotAttnModule_5_NoD
#                                                                  S[0][0]']
#
#  ResUnit_L1_NotAttnModule_6_NoD  (None, 8, 8, 1024)  4096        ['ResUnit_L11_NotAttnModule_5_NoD
#  S (BatchNormalization)                                          S[0][0]']
#
#  ResUnit_L2_NotAttnModule_6_NoD  (None, 8, 8, 1024)  0           ['ResUnit_L1_NotAttnModule_6_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L3_NotAttnModule_6_NoD  (None, 8, 8, 256)   262144      ['ResUnit_L2_NotAttnModule_6_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L4_NotAttnModule_6_NoD  (None, 8, 8, 256)   1024        ['ResUnit_L3_NotAttnModule_6_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L5_NotAttnModule_6_NoD  (None, 8, 8, 256)   0           ['ResUnit_L4_NotAttnModule_6_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L6_NotAttnModule_6_NoD  (None, 8, 8, 256)   589824      ['ResUnit_L5_NotAttnModule_6_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L7_NotAttnModule_6_NoD  (None, 8, 8, 256)   1024        ['ResUnit_L6_NotAttnModule_6_NoDS
#  S (BatchNormalization)                                          [0][0]']
#
#  ResUnit_L8_NotAttnModule_6_NoD  (None, 8, 8, 256)   0           ['ResUnit_L7_NotAttnModule_6_NoDS
#  S (Activation)                                                  [0][0]']
#
#  ResUnit_L9_NotAttnModule_6_NoD  (None, 8, 8, 1024)  262144      ['ResUnit_L8_NotAttnModule_6_NoDS
#  S (Conv2D)                                                      [0][0]']
#
#  ResUnit_L10_NotAttnModule_6_No  (None, 8, 8, 1024)  1048576     ['ResUnit_L2_NotAttnModule_6_NoDS
#  DS (Conv2D)                                                     [0][0]']
#
#  ResUnit_L11_NotAttnModule_6_No  (None, 8, 8, 1024)  0           ['ResUnit_L9_NotAttnModule_6_NoDS
#  DS (Add)                                                        [0][0]',
#                                                                   'ResUnit_L10_NotAttnModule_6_NoD
#                                                                  S[0][0]']
#
#  BN_Out (BatchNormalization)    (None, 8, 8, 1024)   4096        ['ResUnit_L11_NotAttnModule_6_NoD
#                                                                  S[0][0]']
#
#  ReLU_Out (Activation)          (None, 8, 8, 1024)   0           ['BN_Out[0][0]']
#
#  AvgPool_Out (AveragePooling2D)  (None, 1, 1, 1024)  0           ['ReLU_Out[0][0]']
#
#  Flatten_Out (Flatten)          (None, 1024)         0           ['AvgPool_Out[0][0]']
#
#  Final_Out (Dense)              (None, 10)           10250       ['Flatten_Out[0][0]']
#
# ==================================================================================================
# Total params: 11,102,314
# Trainable params: 11,069,418
# Non-trainable params: 32,896
# __________________________________________________________________________________________________

# %%
global summary_filename 
summary_filename = graph_path + '/{}'.format(model_name[1:]) + '_modelsummary.txt'
print(summary_filename)
# Out:
# ./models/ran56_v2/graphs/ran56_v2_modelsummary.txt

# %%
with open(summary_filename, 'w') as f:
    with redirect_stdout(f):
        model.summary()

# %%
# dot_img_file = '/tmp/ran56.png'
# tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# earlyStopping_TrainAcc = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=10)
# callbacks = list()
# callbacks.append(earlyStopping_TrainAcc)

callbacks=[tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor='accuracy'),
          tf.keras.callbacks.ReduceLROnPlateau(patience=5,  monitor='loss')]

# %%
ran56_v2_history = model.fit(datagen.flow(X_train, y_train, batch_size=64, subset='training'), validation_data=datagen.flow(X_train, y_train, batch_size=64, subset='validation'),
                    epochs=200, callbacks=callbacks)
# Out:
# Epoch 1/200
# 625/625 [==============================] - 92s 131ms/step - loss: 1.7901 - accuracy: 0.3168 - val_loss: 1.8217 - val_accuracy: 0.3495 - lr: 0.0010
# Epoch 2/200
# 625/625 [==============================] - 80s 128ms/step - loss: 1.4593 - accuracy: 0.4640 - val_loss: 1.7711 - val_accuracy: 0.4108 - lr: 0.0010
# Epoch 3/200
# 625/625 [==============================] - 80s 127ms/step - loss: 1.2932 - accuracy: 0.5312 - val_loss: 1.4753 - val_accuracy: 0.5121 - lr: 0.0010
# Epoch 4/200
# 625/625 [==============================] - 79s 126ms/step - loss: 1.1777 - accuracy: 0.5773 - val_loss: 1.7737 - val_accuracy: 0.4894 - lr: 0.0010
# Epoch 5/200
# 625/625 [==============================] - 80s 129ms/step - loss: 1.0822 - accuracy: 0.6126 - val_loss: 1.1283 - val_accuracy: 0.5941 - lr: 0.0010
# Epoch 6/200
# 625/625 [==============================] - 86s 138ms/step - loss: 1.0097 - accuracy: 0.6404 - val_loss: 1.3706 - val_accuracy: 0.5906 - lr: 0.0010
# Epoch 7/200
# 625/625 [==============================] - 86s 138ms/step - loss: 0.9486 - accuracy: 0.6668 - val_loss: 1.2382 - val_accuracy: 0.5898 - lr: 0.0010
# Epoch 8/200
# 625/625 [==============================] - 86s 138ms/step - loss: 0.8802 - accuracy: 0.6877 - val_loss: 1.3533 - val_accuracy: 0.5830 - lr: 0.0010
# Epoch 9/200
# 625/625 [==============================] - 87s 138ms/step - loss: 0.8395 - accuracy: 0.7070 - val_loss: 0.9076 - val_accuracy: 0.6841 - lr: 0.0010
# Epoch 10/200
# 625/625 [==============================] - 81s 130ms/step - loss: 0.7995 - accuracy: 0.7212 - val_loss: 0.9715 - val_accuracy: 0.6845 - lr: 0.0010
# Epoch 11/200
# 625/625 [==============================] - 80s 127ms/step - loss: 0.7552 - accuracy: 0.7362 - val_loss: 0.8872 - val_accuracy: 0.6960 - lr: 0.0010
# Epoch 12/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.7290 - accuracy: 0.7457 - val_loss: 0.8442 - val_accuracy: 0.7227 - lr: 0.0010
# Epoch 13/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.6964 - accuracy: 0.7588 - val_loss: 0.7780 - val_accuracy: 0.7366 - lr: 0.0010
# Epoch 14/200
# 625/625 [==============================] - 81s 129ms/step - loss: 0.6644 - accuracy: 0.7711 - val_loss: 0.7963 - val_accuracy: 0.7315 - lr: 0.0010
# Epoch 15/200
# 625/625 [==============================] - 81s 129ms/step - loss: 0.6479 - accuracy: 0.7742 - val_loss: 1.0456 - val_accuracy: 0.6935 - lr: 0.0010
# Epoch 16/200
# 625/625 [==============================] - 80s 127ms/step - loss: 0.6204 - accuracy: 0.7863 - val_loss: 0.7807 - val_accuracy: 0.7323 - lr: 0.0010
# Epoch 17/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.6044 - accuracy: 0.7929 - val_loss: 0.7379 - val_accuracy: 0.7498 - lr: 0.0010
# Epoch 18/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.5819 - accuracy: 0.7996 - val_loss: 0.8818 - val_accuracy: 0.7131 - lr: 0.0010
# Epoch 19/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.5686 - accuracy: 0.8056 - val_loss: 0.7864 - val_accuracy: 0.7427 - lr: 0.0010
# Epoch 20/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.5440 - accuracy: 0.8123 - val_loss: 0.7056 - val_accuracy: 0.7549 - lr: 0.0010
# Epoch 21/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.5360 - accuracy: 0.8142 - val_loss: 0.6247 - val_accuracy: 0.7935 - lr: 0.0010
# Epoch 22/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.5191 - accuracy: 0.8193 - val_loss: 0.6181 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 23/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.5021 - accuracy: 0.8267 - val_loss: 0.6871 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 24/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.4937 - accuracy: 0.8309 - val_loss: 0.6344 - val_accuracy: 0.7857 - lr: 0.0010
# Epoch 25/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.4838 - accuracy: 0.8321 - val_loss: 0.6458 - val_accuracy: 0.7843 - lr: 0.0010
# Epoch 26/200
# 625/625 [==============================] - 75s 121ms/step - loss: 0.4713 - accuracy: 0.8377 - val_loss: 0.6023 - val_accuracy: 0.8027 - lr: 0.0010
# Epoch 27/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.4593 - accuracy: 0.8397 - val_loss: 0.5532 - val_accuracy: 0.8109 - lr: 0.0010
# Epoch 28/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.4436 - accuracy: 0.8490 - val_loss: 0.6255 - val_accuracy: 0.7949 - lr: 0.0010
# Epoch 29/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.4382 - accuracy: 0.8513 - val_loss: 0.6103 - val_accuracy: 0.8027 - lr: 0.0010
# Epoch 30/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.4299 - accuracy: 0.8529 - val_loss: 0.5852 - val_accuracy: 0.8020 - lr: 0.0010
# Epoch 31/200
# 625/625 [==============================] - 77s 124ms/step - loss: 0.4206 - accuracy: 0.8564 - val_loss: 0.5446 - val_accuracy: 0.8169 - lr: 0.0010
# Epoch 32/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.4117 - accuracy: 0.8575 - val_loss: 0.5295 - val_accuracy: 0.8266 - lr: 0.0010
# Epoch 33/200
# 625/625 [==============================] - 78s 124ms/step - loss: 0.3991 - accuracy: 0.8629 - val_loss: 0.5792 - val_accuracy: 0.8085 - lr: 0.0010
# Epoch 34/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.3962 - accuracy: 0.8636 - val_loss: 0.5590 - val_accuracy: 0.8164 - lr: 0.0010
# Epoch 35/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.3858 - accuracy: 0.8683 - val_loss: 0.4887 - val_accuracy: 0.8355 - lr: 0.0010
# Epoch 36/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.3783 - accuracy: 0.8702 - val_loss: 0.4902 - val_accuracy: 0.8323 - lr: 0.0010
# Epoch 37/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.3696 - accuracy: 0.8711 - val_loss: 0.5282 - val_accuracy: 0.8283 - lr: 0.0010
# Epoch 38/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.3604 - accuracy: 0.8761 - val_loss: 0.5823 - val_accuracy: 0.8162 - lr: 0.0010
# Epoch 39/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.3535 - accuracy: 0.8752 - val_loss: 0.4870 - val_accuracy: 0.8372 - lr: 0.0010
# Epoch 40/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.3493 - accuracy: 0.8809 - val_loss: 0.5821 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 41/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.3390 - accuracy: 0.8821 - val_loss: 0.4915 - val_accuracy: 0.8369 - lr: 0.0010
# Epoch 42/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.3359 - accuracy: 0.8824 - val_loss: 0.4911 - val_accuracy: 0.8433 - lr: 0.0010
# Epoch 43/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.3297 - accuracy: 0.8857 - val_loss: 0.5087 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 44/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.3260 - accuracy: 0.8859 - val_loss: 0.5967 - val_accuracy: 0.8056 - lr: 0.0010
# Epoch 45/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.3193 - accuracy: 0.8888 - val_loss: 0.5458 - val_accuracy: 0.8249 - lr: 0.0010
# Epoch 46/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.3084 - accuracy: 0.8942 - val_loss: 0.4346 - val_accuracy: 0.8555 - lr: 0.0010
# Epoch 47/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.3034 - accuracy: 0.8933 - val_loss: 0.4432 - val_accuracy: 0.8509 - lr: 0.0010
# Epoch 48/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2987 - accuracy: 0.8959 - val_loss: 0.5404 - val_accuracy: 0.8298 - lr: 0.0010
# Epoch 49/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.3007 - accuracy: 0.8952 - val_loss: 0.4681 - val_accuracy: 0.8481 - lr: 0.0010
# Epoch 50/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.2971 - accuracy: 0.8978 - val_loss: 0.4651 - val_accuracy: 0.8487 - lr: 0.0010
# Epoch 51/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.2932 - accuracy: 0.8979 - val_loss: 0.5014 - val_accuracy: 0.8376 - lr: 0.0010
# Epoch 52/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2849 - accuracy: 0.9017 - val_loss: 0.4785 - val_accuracy: 0.8507 - lr: 0.0010
# Epoch 53/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.2796 - accuracy: 0.9042 - val_loss: 0.5092 - val_accuracy: 0.8426 - lr: 0.0010
# Epoch 54/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.2755 - accuracy: 0.9048 - val_loss: 0.4285 - val_accuracy: 0.8613 - lr: 0.0010
# Epoch 55/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.2725 - accuracy: 0.9062 - val_loss: 0.5102 - val_accuracy: 0.8468 - lr: 0.0010
# Epoch 56/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.2699 - accuracy: 0.9064 - val_loss: 0.5015 - val_accuracy: 0.8417 - lr: 0.0010
# Epoch 57/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.2605 - accuracy: 0.9087 - val_loss: 0.4344 - val_accuracy: 0.8607 - lr: 0.0010
# Epoch 58/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2585 - accuracy: 0.9101 - val_loss: 0.4086 - val_accuracy: 0.8658 - lr: 0.0010
# Epoch 59/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.2516 - accuracy: 0.9132 - val_loss: 0.4660 - val_accuracy: 0.8534 - lr: 0.0010
# Epoch 60/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2511 - accuracy: 0.9121 - val_loss: 0.4225 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 61/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2442 - accuracy: 0.9160 - val_loss: 0.5611 - val_accuracy: 0.8312 - lr: 0.0010
# Epoch 62/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2395 - accuracy: 0.9165 - val_loss: 0.3754 - val_accuracy: 0.8738 - lr: 0.0010
# Epoch 63/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2376 - accuracy: 0.9166 - val_loss: 0.4507 - val_accuracy: 0.8592 - lr: 0.0010
# Epoch 64/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.2308 - accuracy: 0.9205 - val_loss: 0.4355 - val_accuracy: 0.8602 - lr: 0.0010
# Epoch 65/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2416 - accuracy: 0.9172 - val_loss: 0.4139 - val_accuracy: 0.8693 - lr: 0.0010
# Epoch 66/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2260 - accuracy: 0.9201 - val_loss: 0.4151 - val_accuracy: 0.8721 - lr: 0.0010
# Epoch 67/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2225 - accuracy: 0.9231 - val_loss: 0.5402 - val_accuracy: 0.8357 - lr: 0.0010
# Epoch 68/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2278 - accuracy: 0.9209 - val_loss: 0.4124 - val_accuracy: 0.8680 - lr: 0.0010
# Epoch 69/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2172 - accuracy: 0.9244 - val_loss: 0.4941 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 70/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2161 - accuracy: 0.9241 - val_loss: 0.3918 - val_accuracy: 0.8747 - lr: 0.0010
# Epoch 71/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2196 - accuracy: 0.9223 - val_loss: 0.4786 - val_accuracy: 0.8508 - lr: 0.0010
# Epoch 72/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2132 - accuracy: 0.9254 - val_loss: 0.4129 - val_accuracy: 0.8709 - lr: 0.0010
# Epoch 73/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2087 - accuracy: 0.9281 - val_loss: 0.4976 - val_accuracy: 0.8428 - lr: 0.0010
# Epoch 74/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.2036 - accuracy: 0.9290 - val_loss: 0.4351 - val_accuracy: 0.8636 - lr: 0.0010
# Epoch 75/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.1990 - accuracy: 0.9311 - val_loss: 0.5038 - val_accuracy: 0.8545 - lr: 0.0010
# Epoch 76/200
# 625/625 [==============================] - 77s 124ms/step - loss: 0.2025 - accuracy: 0.9312 - val_loss: 0.5346 - val_accuracy: 0.8418 - lr: 0.0010
# Epoch 77/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.1996 - accuracy: 0.9300 - val_loss: 0.3960 - val_accuracy: 0.8766 - lr: 0.0010
# Epoch 78/200
# 625/625 [==============================] - 75s 121ms/step - loss: 0.1962 - accuracy: 0.9298 - val_loss: 0.4475 - val_accuracy: 0.8611 - lr: 0.0010
# Epoch 79/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1858 - accuracy: 0.9359 - val_loss: 0.5142 - val_accuracy: 0.8545 - lr: 0.0010
# Epoch 80/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1930 - accuracy: 0.9324 - val_loss: 0.5340 - val_accuracy: 0.8395 - lr: 0.0010
# Epoch 81/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1882 - accuracy: 0.9334 - val_loss: 0.4365 - val_accuracy: 0.8682 - lr: 0.0010
# Epoch 82/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1822 - accuracy: 0.9362 - val_loss: 0.5917 - val_accuracy: 0.8301 - lr: 0.0010
# Epoch 83/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1794 - accuracy: 0.9373 - val_loss: 0.4505 - val_accuracy: 0.8612 - lr: 0.0010
# Epoch 84/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1776 - accuracy: 0.9377 - val_loss: 0.4745 - val_accuracy: 0.8579 - lr: 0.0010
# Epoch 85/200
# 625/625 [==============================] - 75s 121ms/step - loss: 0.1812 - accuracy: 0.9357 - val_loss: 0.4268 - val_accuracy: 0.8654 - lr: 0.0010
# Epoch 86/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1781 - accuracy: 0.9386 - val_loss: 0.4367 - val_accuracy: 0.8713 - lr: 0.0010
# Epoch 87/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1778 - accuracy: 0.9381 - val_loss: 0.4582 - val_accuracy: 0.8596 - lr: 0.0010
# Epoch 88/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1729 - accuracy: 0.9404 - val_loss: 0.4574 - val_accuracy: 0.8644 - lr: 0.0010
# Epoch 89/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1682 - accuracy: 0.9406 - val_loss: 0.4033 - val_accuracy: 0.8710 - lr: 0.0010
# Epoch 90/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1694 - accuracy: 0.9409 - val_loss: 0.4059 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 91/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1686 - accuracy: 0.9405 - val_loss: 0.3987 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 92/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1635 - accuracy: 0.9422 - val_loss: 0.4311 - val_accuracy: 0.8705 - lr: 0.0010
# Epoch 93/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1650 - accuracy: 0.9417 - val_loss: 0.3762 - val_accuracy: 0.8858 - lr: 0.0010
# Epoch 94/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1596 - accuracy: 0.9438 - val_loss: 0.4209 - val_accuracy: 0.8759 - lr: 0.0010
# Epoch 95/200
# 625/625 [==============================] - 78s 126ms/step - loss: 0.1571 - accuracy: 0.9463 - val_loss: 0.3784 - val_accuracy: 0.8851 - lr: 0.0010
# Epoch 96/200
# 625/625 [==============================] - 80s 127ms/step - loss: 0.1545 - accuracy: 0.9453 - val_loss: 0.4271 - val_accuracy: 0.8661 - lr: 0.0010
# Epoch 97/200
# 625/625 [==============================] - 82s 131ms/step - loss: 0.1559 - accuracy: 0.9445 - val_loss: 0.4330 - val_accuracy: 0.8774 - lr: 0.0010
# Epoch 98/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.1534 - accuracy: 0.9452 - val_loss: 0.4085 - val_accuracy: 0.8740 - lr: 0.0010
# Epoch 99/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.1518 - accuracy: 0.9470 - val_loss: 0.3866 - val_accuracy: 0.8845 - lr: 0.0010
# Epoch 100/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.1459 - accuracy: 0.9487 - val_loss: 0.5068 - val_accuracy: 0.8641 - lr: 0.0010
# Epoch 101/200
# 625/625 [==============================] - 75s 121ms/step - loss: 0.1502 - accuracy: 0.9481 - val_loss: 0.3744 - val_accuracy: 0.8882 - lr: 0.0010
# Epoch 102/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.1470 - accuracy: 0.9481 - val_loss: 0.4960 - val_accuracy: 0.8607 - lr: 0.0010
# Epoch 103/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.1455 - accuracy: 0.9495 - val_loss: 0.4235 - val_accuracy: 0.8754 - lr: 0.0010
# Epoch 104/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.1455 - accuracy: 0.9492 - val_loss: 0.4324 - val_accuracy: 0.8742 - lr: 0.0010
# Epoch 105/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.1430 - accuracy: 0.9488 - val_loss: 0.4766 - val_accuracy: 0.8598 - lr: 0.0010
# Epoch 106/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.1424 - accuracy: 0.9498 - val_loss: 0.4835 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 107/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.1399 - accuracy: 0.9507 - val_loss: 0.4134 - val_accuracy: 0.8769 - lr: 0.0010
# Epoch 108/200
# 625/625 [==============================] - 75s 121ms/step - loss: 0.1356 - accuracy: 0.9529 - val_loss: 0.4077 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 109/200
# 625/625 [==============================] - 75s 119ms/step - loss: 0.1395 - accuracy: 0.9514 - val_loss: 0.3838 - val_accuracy: 0.8830 - lr: 0.0010
# Epoch 110/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1378 - accuracy: 0.9521 - val_loss: 0.3958 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 111/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1310 - accuracy: 0.9546 - val_loss: 0.4347 - val_accuracy: 0.8766 - lr: 0.0010
# Epoch 112/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1327 - accuracy: 0.9531 - val_loss: 0.4519 - val_accuracy: 0.8794 - lr: 0.0010
# Epoch 113/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1330 - accuracy: 0.9531 - val_loss: 0.4503 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 114/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1237 - accuracy: 0.9567 - val_loss: 0.5584 - val_accuracy: 0.8511 - lr: 0.0010
# Epoch 115/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1267 - accuracy: 0.9557 - val_loss: 0.4243 - val_accuracy: 0.8827 - lr: 0.0010
# Epoch 116/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1253 - accuracy: 0.9566 - val_loss: 0.4095 - val_accuracy: 0.8843 - lr: 0.0010
# Epoch 117/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1251 - accuracy: 0.9562 - val_loss: 0.3766 - val_accuracy: 0.8882 - lr: 0.0010
# Epoch 118/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1223 - accuracy: 0.9576 - val_loss: 0.4056 - val_accuracy: 0.8817 - lr: 0.0010
# Epoch 119/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1211 - accuracy: 0.9568 - val_loss: 0.4811 - val_accuracy: 0.8633 - lr: 0.0010
# Epoch 120/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1196 - accuracy: 0.9594 - val_loss: 0.4516 - val_accuracy: 0.8748 - lr: 0.0010
# Epoch 121/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1259 - accuracy: 0.9560 - val_loss: 0.3705 - val_accuracy: 0.8928 - lr: 0.0010
# Epoch 122/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1166 - accuracy: 0.9594 - val_loss: 0.4696 - val_accuracy: 0.8760 - lr: 0.0010
# Epoch 123/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1164 - accuracy: 0.9602 - val_loss: 0.3944 - val_accuracy: 0.8851 - lr: 0.0010
# Epoch 124/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.1201 - accuracy: 0.9578 - val_loss: 0.4138 - val_accuracy: 0.8851 - lr: 0.0010
# Epoch 125/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1135 - accuracy: 0.9596 - val_loss: 0.3793 - val_accuracy: 0.8857 - lr: 0.0010
# Epoch 126/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1169 - accuracy: 0.9585 - val_loss: 0.4156 - val_accuracy: 0.8794 - lr: 0.0010
# Epoch 127/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1126 - accuracy: 0.9601 - val_loss: 0.4203 - val_accuracy: 0.8835 - lr: 0.0010
# Epoch 128/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1172 - accuracy: 0.9588 - val_loss: 0.4450 - val_accuracy: 0.8782 - lr: 0.0010
# Epoch 129/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1083 - accuracy: 0.9618 - val_loss: 0.3990 - val_accuracy: 0.8877 - lr: 0.0010
# Epoch 130/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1149 - accuracy: 0.9590 - val_loss: 0.5065 - val_accuracy: 0.8612 - lr: 0.0010
# Epoch 131/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.1116 - accuracy: 0.9604 - val_loss: 0.5102 - val_accuracy: 0.8635 - lr: 0.0010
# Epoch 132/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.1095 - accuracy: 0.9617 - val_loss: 0.4481 - val_accuracy: 0.8749 - lr: 0.0010
# Epoch 133/200
# 625/625 [==============================] - 75s 119ms/step - loss: 0.1075 - accuracy: 0.9623 - val_loss: 0.4376 - val_accuracy: 0.8757 - lr: 0.0010
# Epoch 134/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.1122 - accuracy: 0.9602 - val_loss: 0.4043 - val_accuracy: 0.8842 - lr: 0.0010
# Epoch 135/200
# 625/625 [==============================] - 75s 119ms/step - loss: 0.1024 - accuracy: 0.9650 - val_loss: 0.4528 - val_accuracy: 0.8777 - lr: 0.0010
# Epoch 136/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.1046 - accuracy: 0.9630 - val_loss: 0.4407 - val_accuracy: 0.8800 - lr: 0.0010
# Epoch 137/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.1037 - accuracy: 0.9625 - val_loss: 0.4579 - val_accuracy: 0.8785 - lr: 0.0010
# Epoch 138/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.1026 - accuracy: 0.9643 - val_loss: 0.4476 - val_accuracy: 0.8741 - lr: 0.0010
# Epoch 139/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.1037 - accuracy: 0.9648 - val_loss: 0.3883 - val_accuracy: 0.8929 - lr: 0.0010
# Epoch 140/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.0991 - accuracy: 0.9650 - val_loss: 0.5253 - val_accuracy: 0.8734 - lr: 0.0010
# Epoch 141/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.1015 - accuracy: 0.9632 - val_loss: 0.4628 - val_accuracy: 0.8754 - lr: 0.0010
# Epoch 142/200
# 625/625 [==============================] - 82s 131ms/step - loss: 0.1017 - accuracy: 0.9657 - val_loss: 0.4030 - val_accuracy: 0.8840 - lr: 0.0010
# Epoch 143/200
# 625/625 [==============================] - 77s 122ms/step - loss: 0.0973 - accuracy: 0.9652 - val_loss: 0.3979 - val_accuracy: 0.8872 - lr: 0.0010
# Epoch 144/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0995 - accuracy: 0.9646 - val_loss: 0.4254 - val_accuracy: 0.8859 - lr: 0.0010
# Epoch 145/200
# 625/625 [==============================] - 78s 124ms/step - loss: 0.0988 - accuracy: 0.9653 - val_loss: 0.4115 - val_accuracy: 0.8882 - lr: 0.0010
# Epoch 146/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.0959 - accuracy: 0.9665 - val_loss: 0.4076 - val_accuracy: 0.8830 - lr: 0.0010
# Epoch 147/200
# 625/625 [==============================] - 78s 124ms/step - loss: 0.0975 - accuracy: 0.9665 - val_loss: 0.3804 - val_accuracy: 0.8940 - lr: 0.0010
# Epoch 148/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.0903 - accuracy: 0.9680 - val_loss: 0.4177 - val_accuracy: 0.8819 - lr: 0.0010
# Epoch 149/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.1004 - accuracy: 0.9649 - val_loss: 0.4067 - val_accuracy: 0.8846 - lr: 0.0010
# Epoch 150/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0940 - accuracy: 0.9675 - val_loss: 0.4122 - val_accuracy: 0.8857 - lr: 0.0010
# Epoch 151/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0894 - accuracy: 0.9687 - val_loss: 0.4202 - val_accuracy: 0.8929 - lr: 0.0010
# Epoch 152/200
# 625/625 [==============================] - 77s 124ms/step - loss: 0.0936 - accuracy: 0.9675 - val_loss: 0.5006 - val_accuracy: 0.8706 - lr: 0.0010
# Epoch 153/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0940 - accuracy: 0.9678 - val_loss: 0.4289 - val_accuracy: 0.8810 - lr: 0.0010
# Epoch 154/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0921 - accuracy: 0.9684 - val_loss: 0.4408 - val_accuracy: 0.8841 - lr: 0.0010
# Epoch 155/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0887 - accuracy: 0.9694 - val_loss: 0.4191 - val_accuracy: 0.8892 - lr: 0.0010
# Epoch 156/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0905 - accuracy: 0.9684 - val_loss: 0.4368 - val_accuracy: 0.8857 - lr: 0.0010
# Epoch 157/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0909 - accuracy: 0.9675 - val_loss: 0.4539 - val_accuracy: 0.8775 - lr: 0.0010
# Epoch 158/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.0860 - accuracy: 0.9696 - val_loss: 0.4658 - val_accuracy: 0.8786 - lr: 0.0010
# Epoch 159/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.0866 - accuracy: 0.9691 - val_loss: 0.4854 - val_accuracy: 0.8763 - lr: 0.0010
# Epoch 160/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0842 - accuracy: 0.9697 - val_loss: 0.3926 - val_accuracy: 0.8934 - lr: 0.0010
# Epoch 161/200
# 625/625 [==============================] - 75s 121ms/step - loss: 0.0841 - accuracy: 0.9699 - val_loss: 0.3784 - val_accuracy: 0.8940 - lr: 0.0010
# Epoch 162/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0861 - accuracy: 0.9695 - val_loss: 0.4279 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 163/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0843 - accuracy: 0.9708 - val_loss: 0.4382 - val_accuracy: 0.8845 - lr: 0.0010
# Epoch 164/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.0857 - accuracy: 0.9708 - val_loss: 0.4080 - val_accuracy: 0.8941 - lr: 0.0010
# Epoch 165/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.0836 - accuracy: 0.9701 - val_loss: 0.4856 - val_accuracy: 0.8798 - lr: 0.0010
# Epoch 166/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.0831 - accuracy: 0.9710 - val_loss: 0.4168 - val_accuracy: 0.8942 - lr: 0.0010
# Epoch 167/200
# 625/625 [==============================] - 81s 130ms/step - loss: 0.0768 - accuracy: 0.9730 - val_loss: 0.4310 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch 168/200
# 625/625 [==============================] - 80s 129ms/step - loss: 0.0813 - accuracy: 0.9722 - val_loss: 0.4859 - val_accuracy: 0.8781 - lr: 0.0010
# Epoch 169/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.0855 - accuracy: 0.9705 - val_loss: 0.4048 - val_accuracy: 0.8869 - lr: 0.0010
# Epoch 170/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.0793 - accuracy: 0.9724 - val_loss: 0.4258 - val_accuracy: 0.8858 - lr: 0.0010
# Epoch 171/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0817 - accuracy: 0.9703 - val_loss: 0.4811 - val_accuracy: 0.8826 - lr: 0.0010
# Epoch 172/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0823 - accuracy: 0.9715 - val_loss: 0.4576 - val_accuracy: 0.8839 - lr: 0.0010
# Epoch 173/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.0518 - accuracy: 0.9816 - val_loss: 0.3258 - val_accuracy: 0.9124 - lr: 1.0000e-04
# Epoch 174/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0405 - accuracy: 0.9862 - val_loss: 0.3235 - val_accuracy: 0.9166 - lr: 1.0000e-04
# Epoch 175/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.0382 - accuracy: 0.9870 - val_loss: 0.3292 - val_accuracy: 0.9122 - lr: 1.0000e-04
# Epoch 176/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0355 - accuracy: 0.9880 - val_loss: 0.3346 - val_accuracy: 0.9135 - lr: 1.0000e-04
# Epoch 177/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.0305 - accuracy: 0.9898 - val_loss: 0.3478 - val_accuracy: 0.9133 - lr: 1.0000e-04
# Epoch 178/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.0299 - accuracy: 0.9896 - val_loss: 0.3386 - val_accuracy: 0.9145 - lr: 1.0000e-04
# Epoch 179/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0303 - accuracy: 0.9897 - val_loss: 0.3595 - val_accuracy: 0.9148 - lr: 1.0000e-04
# Epoch 180/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0291 - accuracy: 0.9901 - val_loss: 0.3384 - val_accuracy: 0.9173 - lr: 1.0000e-04
# Epoch 181/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0282 - accuracy: 0.9909 - val_loss: 0.3484 - val_accuracy: 0.9149 - lr: 1.0000e-04
# Epoch 182/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.0262 - accuracy: 0.9910 - val_loss: 0.3570 - val_accuracy: 0.9173 - lr: 1.0000e-04
# Epoch 183/200
# 625/625 [==============================] - 74s 119ms/step - loss: 0.0261 - accuracy: 0.9915 - val_loss: 0.3705 - val_accuracy: 0.9137 - lr: 1.0000e-04
# Epoch 184/200
# 625/625 [==============================] - 75s 120ms/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 0.3582 - val_accuracy: 0.9176 - lr: 1.0000e-04
# Epoch 185/200
# 625/625 [==============================] - 76s 121ms/step - loss: 0.0264 - accuracy: 0.9906 - val_loss: 0.3540 - val_accuracy: 0.9166 - lr: 1.0000e-04
# Epoch 186/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 0.3631 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 187/200
# 625/625 [==============================] - 81s 129ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.3492 - val_accuracy: 0.9158 - lr: 1.0000e-04
# Epoch 188/200
# 625/625 [==============================] - 81s 129ms/step - loss: 0.0233 - accuracy: 0.9919 - val_loss: 0.3796 - val_accuracy: 0.9146 - lr: 1.0000e-04
# Epoch 189/200
# 625/625 [==============================] - 76s 122ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.3699 - val_accuracy: 0.9156 - lr: 1.0000e-04
# Epoch 190/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.3520 - val_accuracy: 0.9188 - lr: 1.0000e-04
# Epoch 191/200
# 625/625 [==============================] - 80s 129ms/step - loss: 0.0233 - accuracy: 0.9921 - val_loss: 0.3647 - val_accuracy: 0.9149 - lr: 1.0000e-04
# Epoch 192/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.0215 - accuracy: 0.9924 - val_loss: 0.3697 - val_accuracy: 0.9173 - lr: 1.0000e-04
# Epoch 193/200
# 625/625 [==============================] - 77s 123ms/step - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.3670 - val_accuracy: 0.9176 - lr: 1.0000e-04
# Epoch 194/200
# 625/625 [==============================] - 79s 126ms/step - loss: 0.0226 - accuracy: 0.9922 - val_loss: 0.3927 - val_accuracy: 0.9112 - lr: 1.0000e-04
# Epoch 195/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0226 - accuracy: 0.9923 - val_loss: 0.3417 - val_accuracy: 0.9175 - lr: 1.0000e-04
# Epoch 196/200
# 625/625 [==============================] - 80s 129ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.3688 - val_accuracy: 0.9164 - lr: 1.0000e-04
# Epoch 197/200
# 625/625 [==============================] - 80s 128ms/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.3708 - val_accuracy: 0.9140 - lr: 1.0000e-04
# Epoch 198/200
# 625/625 [==============================] - 79s 127ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.3632 - val_accuracy: 0.9149 - lr: 1.0000e-04
# Epoch 199/200
# 625/625 [==============================] - 77s 124ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.3772 - val_accuracy: 0.9171 - lr: 1.0000e-04
# Epoch 200/200
# 625/625 [==============================] - 78s 125ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.3686 - val_accuracy: 0.9163 - lr: 1.0000e-04

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=1)
y_true = np.argmax(y_test,axis=1)

# %%
acc = accuracy_score(y_true, preds)
cr=  classification_report(y_true, preds)
print(f"Accuracy: {acc}")
print(cr)
# Out:
# Accuracy: 0.9207
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1000
#            1       0.94      0.97      0.96      1000
#            2       0.90      0.91      0.90      1000
#            3       0.87      0.85      0.86      1000
#            4       0.92      0.92      0.92      1000
#            5       0.93      0.83      0.88      1000
#            6       0.90      0.96      0.93      1000
#            7       0.95      0.94      0.94      1000
#            8       0.96      0.94      0.95      1000
#            9       0.92      0.95      0.94      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000

# %%
plot_loss_filename = graph_path + '/ran56_v2_Loss.png'
print(plot_loss_filename)
plot_acc_filename = graph_path + '/ran56_v2_Accuracy.png'
print(plot_acc_filename)
# Out:
# ./models/ran56_v2/graphs/ran56_v2_Loss.png
# ./models/ran56_v2/graphs/ran56_v2_Accuracy.png

# %%
plt.figure(figsize=(16,12))
plt.title("Attention 56, v2: Training Loss vs. Validation Loss", fontsize=18)
plt.plot(ran56_v2_history.history['loss'], label='training loss', color='red')
plt.plot(ran56_v2_history.history['val_loss'], label = 'validation loss', color='blue')
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=12)
plt.savefig(plot_loss_filename)
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.title("Attention 56, v2: Training Accuracy vs Validation Accuracy", fontsize=18)
plt.plot(ran56_v2_history.history['accuracy'], label='training accuracy', color='g')
plt.plot(ran56_v2_history.history['val_accuracy'], label = 'validation accuracy', color='c')
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=12)
plt.savefig(plot_acc_filename)
plt.show()

# %%
history_filename = history_path + '/ran56_v2_history_' + time.ctime().replace(' ','_').replace(':','_')
print(history_filename)
# Out:
# ./models/ran56_v2/history/ran56_v2_history_Mon_Dec_20_00_15_41_2021

# %%
np.save(history_filename+'.npy', ran56_v2_history.history)

# %%
# ran56_v2_history=np.load(history_filename+'.npy', allow_pickle='TRUE').item()

# %%
model.save(saved_model_path + '/ran56_v2')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Model_Input with unsupported characters which will be renamed to model_input in the SavedModel.
# INFO:tensorflow:Assets written to: ./models/ran56_v2/saved_models/ran56_v2\assets
# INFO:tensorflow:Assets written to: ./models/ran56_v2/saved_models/ran56_v2\assets
# C:\Users\suman\anaconda3\envs\p38\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\suman\anaconda3\envs\p38\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)
